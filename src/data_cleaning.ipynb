# %%
# Import libraries
 
import pandas as pd

# %%
# upload dataset

movie_df = pd.read_json('rottentomatoes_movies_20260107_115630.json')

# Make a copy of the original dataframe
df = movie_df.copy()

# %%
df.head()
# Out:
#                                 Name Tomatoes_score Popcorn_score  \
# 0  Weathered: After the LA Firestorm
# 1                          Labyrinth            77%           86%
# 2                       Jana Nayagan
# 3                            Primate            91%
# 4                  Is This Thing On?            86%           88%
#
#                         Date
# 0        Opened Jan 07, 2026
# 1  Re-releasing Jan 08, 2026
# 2         Opens Jan 08, 2026
# 3         Opens Jan 09, 2026
# 4         Opens Jan 09, 2026

# %%
df.shape
# Out:
# (65, 4)
